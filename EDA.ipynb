# %%
import pandas as pd

# %%
data = pd.read_excel(r"C:\Users\chara\OneDrive\Desktop\Raw_data.xlsx")
data
# Out:
#      Name          Domain      Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34yeras     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45'yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#      NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics      NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics    67-yr        NaN   30000-  5+ year
# 5     Kim             NLP     55yr      Delhi  6000^$0      10+

# %%
data.shape
# Out:
# (6, 6)

# %%
len(data)
# Out:
# 6

# %%
data.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
len(data.columns)
# Out:
# 6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
data
# Out:
#      Name          Domain      Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34yeras     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45'yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#      NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics      NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics    67-yr        NaN   30000-  5+ year
# 5     Kim             NLP     55yr      Delhi  6000^$0      10+

# %%
data['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
data['Domain']
# Out:
# 0     Datascience#$
# 1           Testing
# 2    Dataanalyst^^#
# 3       Ana^^lytics
# 4        Statistics
# 5               NLP
# Name: Domain, dtype: object

# %%
data['Age']
# Out:
# 0    34yeras
# 1      45'yr
# 2        NaN
# 3        NaN
# 4      67-yr
# 5       55yr
# Name: Age, dtype: object

# %%
data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
data['Salary']
# Out:
# 0     5^00#0
# 1    10%%000
# 2    1$5%000
# 3     2000^0
# 4     30000-
# 5    6000^$0
# Name: Salary, dtype: object

# %%
data['Exp']
# Out:
# 0         2+
# 1         <3
# 2     4> yrs
# 3        NaN
# 4    5+ year
# 5        10+
# Name: Exp, dtype: object

# %%
data[['Name','Domain','Age','Location','Exp']]
# Out:
#      Name          Domain      Age   Location      Exp
# 0    Mike   Datascience#$  34yeras     Mumbai       2+
# 1  Teddy^         Testing    45'yr  Bangalore       <3
# 2   Uma#r  Dataanalyst^^#      NaN        NaN   4> yrs
# 3    Jane     Ana^^lytics      NaN   Hyderbad      NaN
# 4  Uttam*      Statistics    67-yr        NaN  5+ year
# 5     Kim             NLP     55yr      Delhi      10+

# %% [markdown]
# # DATA CLEANING

# %%
data['Name']
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
data['Name'] = data['Name'].str.replace(r'\W','',regex = True)

# %%
data['Name']
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
data['Domain'] = data['Domain'].str.replace(r'\W','',regex=True)

# %%
data['Domain']
# Out:
# 0    Datascience
# 1        Testing
# 2    Dataanalyst
# 3      Analytics
# 4     Statistics
# 5            NLP
# Name: Domain, dtype: object

# %%
data['Age'] = data['Age'].str.replace(r'\W','',regex=True)

# %%
data['Age']
# Out:
# 0    34yeras
# 1       45yr
# 2        NaN
# 3        NaN
# 4       67yr
# 5       55yr
# Name: Age, dtype: object

# %%
data['Age'] = data['Age'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chara\AppData\Local\Temp\ipykernel_13020\1163978803.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['Age'] = data['Age'].str.extract('(\d+)')

# %%
data['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
data['Salary'] = data['Salary'].str.replace(r'\W','',regex=True)

# %%
data['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: object

# %%
data['Exp'] = data['Exp'].str.replace(r'\W','',regex=True)

# %%
data['Exp']
# Out:
# 0        2
# 1        3
# 2     4yrs
# 3      NaN
# 4    5year
# 5       10
# Name: Exp, dtype: object

# %%
data['Exp'] = data['Exp'].str.extract('(\d+)')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\chara\AppData\Local\Temp\ipykernel_13020\1056166233.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data['Exp'] = data['Exp'].str.extract('(\d+)')

# %%
data['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    NaN
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
data
# Out:
#     Name       Domain  Age   Location Salary  Exp  exp
# 0   Mike  Datascience   34     Mumbai   5000    2    2
# 1  Teddy      Testing   45  Bangalore  10000    3    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN  NaN
# 4  Uttam   Statistics   67        NaN  30000    5    5
# 5    Kim          NLP   55      Delhi  60000   10   10

# %%
clean_data = data.copy()

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp  exp
# 0   Mike  Datascience   34     Mumbai   5000    2    2
# 1  Teddy      Testing   45  Bangalore  10000    3    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN  NaN
# 4  Uttam   Statistics   67        NaN  30000    5    5
# 5    Kim          NLP   55      Delhi  60000   10   10

# %%
data = data.drop(['exp'], axis=1)

# %%
data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
Clean_data = data.copy()

# %%
Clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %% [markdown]
# # Cleaning missing values

# %%
Clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       4 non-null      object
#  3   Location  4 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       5 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
import numpy as np

# %%
Clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp
# 0   Mike  Datascience   34     Mumbai   5000    2
# 1  Teddy      Testing   45  Bangalore  10000    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN
# 4  Uttam   Statistics   67        NaN  30000    5
# 5    Kim          NLP   55      Delhi  60000   10

# %%
Clean_data.head(1)
# Out:
#    Name       Domain Age Location Salary Exp
# 0  Mike  Datascience  34   Mumbai   5000   2

# %%
Clean_data['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
Clean_data['Age'] = Clean_data['Age'].fillna(np.mean(pd.to_numeric(Clean_data['Age'])))

# %%
Clean_data['Age']
# Out:
# 0       34
# 1       45
# 2    50.25
# 3    50.25
# 4       67
# 5       55
# Name: Age, dtype: object

# %%
Clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  NaN
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
Clean_data['Exp'] = Clean_data['Exp'].fillna(np.mean(pd.to_numeric(Clean_data['Exp'])))

# %%
Clean_data['Exp']
# Out:
# 0      2
# 1      3
# 2      4
# 3    4.8
# 4      5
# 5     10
# Name: Exp, dtype: object

# %%
Clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25        NaN  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67        NaN  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
Clean_data['Location'] = Clean_data['Location'].fillna(Clean_data['Location'].mode()[0])

# %%
Clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2     Hyderbad
# 3     Hyderbad
# 4     Hyderbad
# 5        Delhi
# Name: Location, dtype: object

# %%
Clean_data
# Out:
#     Name       Domain    Age   Location Salary  Exp
# 0   Mike  Datascience     34     Mumbai   5000    2
# 1  Teddy      Testing     45  Bangalore  10000    3
# 2   Umar  Dataanalyst  50.25   Hyderbad  15000    4
# 3   Jane    Analytics  50.25   Hyderbad  20000  4.8
# 4  Uttam   Statistics     67   Hyderbad  30000    5
# 5    Kim          NLP     55      Delhi  60000   10

# %%
Clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      object
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      object
#  5   Exp       6 non-null      object
# dtypes: object(6)
# memory usage: 420.0+ bytes

# %%
Clean_data['Age'] = Clean_data['Age'].astype(int)

# %%
Clean_data['Salary'] = Clean_data['Salary'].astype(int)

# %%
Clean_data['Exp'] = Clean_data['Exp'].astype(int)

# %%
Clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      object
#  1   Domain    6 non-null      object
#  2   Age       6 non-null      int32
#  3   Location  6 non-null      object
#  4   Salary    6 non-null      int32
#  5   Exp       6 non-null      int32
# dtypes: int32(3), object(3)
# memory usage: 348.0+ bytes

# %%
Clean_data['Name'] = Clean_data['Name'].astype('category')

# %%
Clean_data['Domain'] = Clean_data['Domain'].astype('category')

# %%
Clean_data['Location'] = Clean_data['Location'].astype('category')

# %%
Clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      6 non-null      category
#  1   Domain    6 non-null      category
#  2   Age       6 non-null      int32
#  3   Location  6 non-null      category
#  4   Salary    6 non-null      int32
#  5   Exp       6 non-null      int32
# dtypes: category(3), int32(3)
# memory usage: 866.0 bytes

# %%
clean_data
# Out:
#     Name       Domain  Age   Location Salary  Exp  exp
# 0   Mike  Datascience   34     Mumbai   5000    2    2
# 1  Teddy      Testing   45  Bangalore  10000    3    3
# 2   Umar  Dataanalyst  NaN        NaN  15000    4    4
# 3   Jane    Analytics  NaN   Hyderbad  20000  NaN  NaN
# 4  Uttam   Statistics   67        NaN  30000    5    5
# 5    Kim          NLP   55      Delhi  60000   10   10

# %%
Clean_data.to_csv('Clean_data.csv')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\chara'

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
Clean_data['Salary']
# Out:
# 0     5000
# 1    10000
# 2    15000
# 3    20000
# 4    30000
# 5    60000
# Name: Salary, dtype: int32

# %%
vis = sns.distplot(Clean_data['Salary'])

# %%
plt.rcParams['figure.figsize'] = 10,6

# %%
vis = sns.distplot(Clean_data['Salary'])

# %%
vis2 = sns.lmplot(data = Clean_data, x = 'Exp', y = 'Salary')

# %%
vis3 = sns.lmplot(data = Clean_data, x = 'Exp', y = 'Salary', fit_reg = False)

# %%
Clean_data
# Out:
#     Name       Domain  Age   Location  Salary  Exp
# 0   Mike  Datascience   34     Mumbai    5000    2
# 1  Teddy      Testing   45  Bangalore   10000    3
# 2   Umar  Dataanalyst   50   Hyderbad   15000    4
# 3   Jane    Analytics   50   Hyderbad   20000    4
# 4  Uttam   Statistics   67   Hyderbad   30000    5
# 5    Kim          NLP   55      Delhi   60000   10
